# %% [markdown]
# <a href="https://colab.research.google.com/github/sezall/Enerdy-consumption-in-india/blob/main/Energy_consumption.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Importing libraries**
# Importing important libraries such as numpy, pandas, matplotlib etc.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import calendar
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # **Reading dataset**
#
# *  Changing datatype of 'Date' column from string to Date type
# *   Resetting Index

# %%
power=pd.read_csv("energygen.csv",parse_dates=['Date'])
state_region=pd.read_csv('State_Region_corrected.csv')

# %%
power.head()
# Out:
#    index       Date        Region Thermal Generation Actual (in MU)  \
# 0      0 2017-09-01      Northern                            624.23
# 1      1 2017-09-01       Western                          1,106.89
# 2      2 2017-09-01      Southern                            576.66
# 3      3 2017-09-01       Eastern                            441.02
# 4      4 2017-09-01  NorthEastern                             29.11
#
#   Thermal Generation Estimated (in MU)  Nuclear Generation Actual (in MU)  \
# 0                               484.21                              30.36
# 1                             1,024.33                              25.17
# 2                               578.55                              62.73
# 3                               429.39                                NaN
# 4                                15.91                                NaN
#
#    Nuclear Generation Estimated (in MU)  Hydro Generation Actual (in MU)  \
# 0                                 35.57                           273.27
# 1                                  3.81                            72.00
# 2                                 49.80                           111.57
# 3                                   NaN                            85.94
# 4                                   NaN                            24.64
#
#    Hydro Generation Estimated (in MU)
# 0                              320.81
# 1                               21.53
# 2                               64.78
# 3                               69.36
# 4                               21.21

# %%
power=power.set_index('index')

# %%
power.head()
# Out:
#             Date        Region Thermal Generation Actual (in MU)  \
# index
# 0     2017-09-01      Northern                            624.23
# 1     2017-09-01       Western                          1,106.89
# 2     2017-09-01      Southern                            576.66
# 3     2017-09-01       Eastern                            441.02
# 4     2017-09-01  NorthEastern                             29.11
#
#       Thermal Generation Estimated (in MU)  Nuclear Generation Actual (in MU)  \
# index
# 0                                   484.21                              30.36
# 1                                 1,024.33                              25.17
# 2                                   578.55                              62.73
# 3                                   429.39                                NaN
# 4                                    15.91                                NaN
#
#        Nuclear Generation Estimated (in MU)  Hydro Generation Actual (in MU)  \
# index
# 0                                     35.57                           273.27
# 1                                      3.81                            72.00
# 2                                     49.80                           111.57
# 3                                       NaN                            85.94
# 4                                       NaN                            24.64
#
#        Hydro Generation Estimated (in MU)
# index
# 0                                  320.81
# 1                                   21.53
# 2                                   64.78
# 3                                   69.36
# 4                                   21.21

# %% [markdown]
# # **Exploratory Data Analysis**
# Extracting basic information about the dataset

# %%
power.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4945 entries, 0 to 309
# Data columns (total 8 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   Date                                  4945 non-null   datetime64[ns]
#  1   Region                                4945 non-null   object
#  2   Thermal Generation Actual (in MU)     4945 non-null   object
#  3   Thermal Generation Estimated (in MU)  4945 non-null   object
#  4   Nuclear Generation Actual (in MU)     2967 non-null   float64
#  5   Nuclear Generation Estimated (in MU)  2967 non-null   float64
#  6   Hydro Generation Actual (in MU)       4945 non-null   float64
#  7   Hydro Generation Estimated (in MU)    4945 non-null   float64
# dtypes: datetime64[ns](1), float64(4), object(3)
# memory usage: 347.7+ KB

# %% [markdown]
# Since 'Thermal Generation Actual (in MU)' and 'Thermal Generation
# Estimated (in MU)' are float values but cosidered as object by default (due to presence of commas[,]) these have to be changed to float datatypes

# %%
power['Thermal Generation Actual (in MU)'] = power['Thermal Generation Actual (in MU)'].str.replace(',','').astype('float')
power['Thermal Generation Estimated (in MU)'] = power['Thermal Generation Estimated (in MU)'].str.replace(',','').astype('float')

# %%
power.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4945 entries, 0 to 309
# Data columns (total 8 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   Date                                  4945 non-null   datetime64[ns]
#  1   Region                                4945 non-null   object
#  2   Thermal Generation Actual (in MU)     4945 non-null   float64
#  3   Thermal Generation Estimated (in MU)  4945 non-null   float64
#  4   Nuclear Generation Actual (in MU)     2967 non-null   float64
#  5   Nuclear Generation Estimated (in MU)  2967 non-null   float64
#  6   Hydro Generation Actual (in MU)       4945 non-null   float64
#  7   Hydro Generation Estimated (in MU)    4945 non-null   float64
# dtypes: datetime64[ns](1), float64(6), object(1)
# memory usage: 347.7+ KB

# %%
power.describe()
# Out:
#                                 Date  Thermal Generation Actual (in MU)  \
# count                           4945                        4945.000000
# mean   2019-01-14 07:16:48.291203328                         603.978358
# min              2017-09-01 00:00:00                          12.340000
# 25%              2018-05-07 00:00:00                         470.050000
# 50%              2019-01-10 00:00:00                         615.280000
# 75%              2019-09-14 00:00:00                         689.530000
# max              2020-08-01 00:00:00                        1395.970000
# std                              NaN                         383.534208
#
#        Thermal Generation Estimated (in MU)  \
# count                           4945.000000
# mean                             575.395116
# min                               12.380000
# 25%                              427.460000
# 50%                              535.980000
# 75%                              672.740000
# max                             1442.380000
# std                              383.387299
#
#        Nuclear Generation Actual (in MU)  \
# count                        2967.000000
# mean                           37.242208
# min                             0.000000
# 25%                            26.140000
# 50%                            30.720000
# 75%                            46.830000
# max                            68.740000
# std                            15.883968
#
#        Nuclear Generation Estimated (in MU)  Hydro Generation Actual (in MU)  \
# count                           2967.000000                      4945.000000
# mean                              36.987877                        73.305921
# min                                0.000000                         0.000000
# 25%                               30.190000                        26.910000
# 50%                               34.840000                        52.960000
# 75%                               43.075000                        85.940000
# max                               76.640000                       348.720000
# std                               11.491292                        74.482145
#
#        Hydro Generation Estimated (in MU)
# count                         4945.000000
# mean                            76.842965
# min                              0.000000
# 25%                             23.310000
# 50%                             50.270000
# 75%                             95.800000
# max                            397.380000
# std                             82.043952

# %%
power.isna().sum()
# Out:
# Date                                       0
# Region                                     0
# Thermal Generation Actual (in MU)          0
# Thermal Generation Estimated (in MU)       0
# Nuclear Generation Actual (in MU)       1978
# Nuclear Generation Estimated (in MU)    1978
# Hydro Generation Actual (in MU)            0
# Hydro Generation Estimated (in MU)         0
# dtype: int64

# %% [markdown]
# # **Heatmap indicating null values in the Dataset**

# %%
plt.figure(figsize=(8,5))
plt.show(sns.heatmap(power.isnull()))

# %% [markdown]
# *   Since there are no Nuclear Energy Generation plants in Eastern and North-Eastern region, values for them are missing.
# *   These missing values can be replaced with 0 since no energy was generated in that area.

# %%
power=power.fillna(0)

# %%
power.Region.unique()
# Out:
# array(['Northern', 'Western', 'Southern', 'Eastern', 'NorthEastern'],
#       dtype=object)

# %% [markdown]
# # **Line-Graphs showing Estimated vs. Actual power generation for different Energy types**

# %%
sns.set(rc={'figure.figsize':(18,10)})
sns.lineplot(x=power['Date'],y=power['Thermal Generation Actual (in MU)'],label='Actual').set_title('THERMAL POWER GENERATION ESTIMATED VS. ACTUAL',fontsize=30)
sns.lineplot(x=power['Date'],y=power['Thermal Generation Estimated (in MU)'],label='Estimated')
plt.show()

# %%
sns.set(rc={'figure.figsize':(18,10)})
sns.lineplot(x=power['Date'],y=power['Nuclear Generation Actual (in MU)'],label='Actual').set_title('NUCLEAR POWER GENERATION ESTIMATED VS. ACTUAL',fontsize=30)
sns.lineplot(x=power['Date'],y=power['Nuclear Generation Estimated (in MU)'],label='Estimated')
plt.show()

# %%
sns.set(rc={'figure.figsize':(18,10)})
sns.lineplot(x=power['Date'],y=power['Hydro Generation Actual (in MU)'],label='Actual').set_title('HYDRO POWER GENERATION ESTIMATED VS. ACTUAL',fontsize=30)
sns.lineplot(x=power['Date'],y=power['Hydro Generation Estimated (in MU)'],label='Estimated')
plt.show()

# %%
plt.figure(figsize=(22, 6))

ax1 = plt.subplot(1,2,2)
ax1 = sns.lineplot(data=power, x='Date', y='Thermal Generation Actual (in MU)', label='Thermal')
ax1 = sns.lineplot(data=power, x='Date', y='Nuclear Generation Actual (in MU)', label='Nuclear')
ax1 = sns.lineplot(data=power, x='Date', y='Hydro Generation Actual (in MU)', label='Hydro')
plt.title('Actual Energy Resorces',fontdict = {'fontsize' : 20})

ax2 = plt.subplot(1,2,1)
ax2 = sns.lineplot(data=power, x='Date', y='Thermal Generation Estimated (in MU)', label='Thermal')
ax2 = sns.lineplot(data=power, x='Date', y='Nuclear Generation Estimated (in MU)', label='Nuclear')
ax2 = sns.lineplot(data=power, x='Date', y='Hydro Generation Estimated (in MU)', label='Hydro')
plt.title('Estimated Energy Resorces',fontdict = {'fontsize' : 20})

plt.show()

# %% [markdown]
# *  Thermal energy turns out to be the most dominant power generated all over the country.

# %% [markdown]
# # **Calculating total Actual and Estimated Powers**

# %%
power['Total Actual Power']=power['Thermal Generation Actual (in MU)']+power['Nuclear Generation Actual (in MU)']+power['Hydro Generation Actual (in MU)']
power['Total Estimated Power']=power['Thermal Generation Estimated (in MU)']+power['Nuclear Generation Estimated (in MU)']+power['Hydro Generation Estimated (in MU)']

# %%
power.head()
# Out:
#             Date        Region  Thermal Generation Actual (in MU)  \
# index
# 0     2017-09-01      Northern                             624.23
# 1     2017-09-01       Western                            1106.89
# 2     2017-09-01      Southern                             576.66
# 3     2017-09-01       Eastern                             441.02
# 4     2017-09-01  NorthEastern                              29.11
#
#        Thermal Generation Estimated (in MU)  \
# index
# 0                                    484.21
# 1                                   1024.33
# 2                                    578.55
# 3                                    429.39
# 4                                     15.91
#
#        Nuclear Generation Actual (in MU)  \
# index
# 0                                  30.36
# 1                                  25.17
# 2                                  62.73
# 3                                   0.00
# 4                                   0.00
#
#        Nuclear Generation Estimated (in MU)  Hydro Generation Actual (in MU)  \
# index
# 0                                     35.57                           273.27
# 1                                      3.81                            72.00
# 2                                     49.80                           111.57
# 3                                      0.00                            85.94
# 4                                      0.00                            24.64
#
#        Hydro Generation Estimated (in MU)  Total Actual Power  \
# index
# 0                                  320.81              927.86
# 1                                   21.53             1204.06
# 2                                   64.78              750.96
# 3                                   69.36              526.96
# 4                                   21.21               53.75
#
#        Total Estimated Power
# index
# 0                     840.59
# 1                    1049.67
# 2                     693.13
# 3                     498.75
# 4                      37.12

# %% [markdown]
# # **Power Generation by Region (Estimated Vs. Actual)**

# %%
plt.figure(figsize=(22, 6))

ax1 = plt.subplot(1,2,2)
ax1 = sns.lineplot(data=power, x='Date', y='Total Actual Power', hue='Region')
plt.title('Total Actual Power by Regions',fontdict = {'fontsize' : 20})

ax1 = plt.subplot(1,2,1)
ax1 = sns.lineplot(data=power, x='Date', y='Total Estimated Power', hue='Region')
plt.title('Total Estimated Power by Regions',fontdict = {'fontsize' : 20})

plt.show()

# %% [markdown]
# *  The graph indicates that maximum power is generated in the Western region followed by the Northern and then the Southern region.
#
#
# # **Calculating Power Generation grouped by Month**

# %%
power_month = power[['Date','Total Actual Power','Total Estimated Power']]
power_month['Month']=power_month['Date'].dt.month
power_month
# Out:
#             Date  Total Actual Power  Total Estimated Power  Month
# index
# 0     2017-09-01              927.86                 840.59      9
# 1     2017-09-01             1204.06                1049.67      9
# 2     2017-09-01              750.96                 693.13      9
# 3     2017-09-01              526.96                 498.75      9
# 4     2017-09-01               53.75                  37.12      9
# ...          ...                 ...                    ...    ...
# 305   2020-08-01             1045.07                 978.35      8
# 306   2020-08-01             1213.04                1319.01      8
# 307   2020-08-01              649.98                 519.06      8
# 308   2020-08-01              570.08                 640.81      8
# 309   2020-08-01               64.29                  62.77      8
#
# [4945 rows x 4 columns]

# %%
power_month['Month'] = power_month['Month'].apply(lambda x: calendar.month_abbr[int(x)])

# %%
power_month
# Out:
#             Date  Total Actual Power  Total Estimated Power Month
# index
# 0     2017-09-01              927.86                 840.59   Sep
# 1     2017-09-01             1204.06                1049.67   Sep
# 2     2017-09-01              750.96                 693.13   Sep
# 3     2017-09-01              526.96                 498.75   Sep
# 4     2017-09-01               53.75                  37.12   Sep
# ...          ...                 ...                    ...   ...
# 305   2020-08-01             1045.07                 978.35   Aug
# 306   2020-08-01             1213.04                1319.01   Aug
# 307   2020-08-01              649.98                 519.06   Aug
# 308   2020-08-01              570.08                 640.81   Aug
# 309   2020-08-01               64.29                  62.77   Aug
#
# [4945 rows x 4 columns]

# %%
# Group data by month and sum the relevant columns, excluding the 'Date' column
power_month = power_month.groupby('Month')[['Total Actual Power', 'Total Estimated Power']].sum()

# Reset the index to make 'Month' a regular column again
power_month.reset_index(inplace=True)

# Display the modified DataFrame
power_month
# Out:
#    Month  Total Actual Power  Total Estimated Power
# 0    Apr           213513.05              212048.02
# 1    Aug           222086.50              209302.58
# 2    Dec           308104.51              295469.50
# 3    Feb           291998.90              283755.93
# 4    Jan           316118.41              304111.42
# 5    Jul           324230.03              315703.55
# 6    Jun           333726.56              313241.10
# 7    Mar           276712.36              267485.50
# 8    May           227504.28              226703.85
# 9    Nov           299675.62              287673.20
# 10   Oct           323916.84              309780.29
# 11   Sep           322081.33              309785.40

# %%
power_month['Month'] = pd.Categorical(power_month.Month,categories=calendar.month_abbr[1:], ordered=True)
power_month=power_month.sort_values('Month')
power_month.reset_index(drop=True, inplace=True)
power_month
# Out:
#    Month  Total Actual Power  Total Estimated Power
# 0    Jan           316118.41              304111.42
# 1    Feb           291998.90              283755.93
# 2    Mar           276712.36              267485.50
# 3    Apr           213513.05              212048.02
# 4    May           227504.28              226703.85
# 5    Jun           333726.56              313241.10
# 6    Jul           324230.03              315703.55
# 7    Aug           222086.50              209302.58
# 8    Sep           322081.33              309785.40
# 9    Oct           323916.84              309780.29
# 10   Nov           299675.62              287673.20
# 11   Dec           308104.51              295469.50

# %% [markdown]
# # **Month-wise Estimated Vs. Actual Power Generation**

# %%
power_month.plot(kind='bar',x='Month',y=['Total Actual Power','Total Estimated Power'])
# Out:
# <Axes: xlabel='Month'>

# %%
state_region
# Out:
#                 State / Union territory (UT)  Area (km2)        Region  \
# 0                                  Rajasthan      342239      Northern
# 1                             Madhya Pradesh      308350       Central
# 2                                Maharashtra      307713       Western
# 3                              Uttar Pradesh      240928      Northern
# 4                                    Gujarat      196024       Western
# 5                                  Karnataka      191791      Southern
# 6                             Andhra Pradesh      162970      Southern
# 7                                     Odisha      155707       Eastern
# 8                               Chhattisgarh      135191       Central
# 9                                 Tamil Nadu      130058      Southern
# 10                                 Telangana      112077      Southern
# 11                                     Bihar       94163       Eastern
# 12                               West Bengal       88752       Eastern
# 13                         Arunachal Pradesh       83743  Northeastern
# 14                                 Jharkhand       79714       Eastern
# 15                                     Assam       78438  Northeastern
# 16                                    Ladakh       59146      Northern
# 17                          Himachal Pradesh       55673      Northern
# 18                               Uttarakhand       53483      Northern
# 19                                    Punjab       50362      Northern
# 20                                   Haryana       44212      Northern
# 21                         Jammu and Kashmir       42241      Northern
# 22                                    Kerala       38863      Southern
# 23                                 Meghalaya       22429  Northeastern
# 24                                   Manipur       22327  Northeastern
# 25                                   Mizoram       21081  Northeastern
# 26                                  Nagaland       16579  Northeastern
# 27                                   Tripura       10486  Northeastern
# 28                                    Sikkim        7096  Northeastern
# 29                                       Goa        3702       Western
# 30                                     Delhi        1483      Northern
# 31  Dadra and Nagar Haveli and Daman and Diu         603       Western
# 32                                Puducherry         492      Southern
# 33                                Chandigarh         114      Northern
#
#     National Share (%)
# 0               10.550
# 1                9.370
# 2                9.360
# 3                7.330
# 4                5.960
# 5                5.830
# 6                4.870
# 7                4.730
# 8                4.110
# 9                3.950
# 10               3.490
# 11               2.860
# 12               2.700
# 13               2.540
# 14               2.420
# 15               2.380
# 16               1.800
# 17               1.700
# 18               1.620
# 19               1.530
# 20               1.340
# 21               1.280
# 22               1.180
# 23               0.680
# 24               0.680
# 25               0.640
# 26               0.500
# 27               0.310
# 28               0.210
# 29               0.110
# 30               0.040
# 31               0.010
# 32               0.010
# 33               0.003

# %%
state_region = state_region.replace('Northeastern','NorthEastern')

# %% [markdown]
# # **State-wise Distribution of National-Share**

# %%
sns.set(rc={'figure.figsize':(10,8)})
sns.barplot(x='National Share (%)',y='State / Union territory (UT)',data=state_region)
plt.show()

# %% [markdown]
# # **Region-wise distribution**

# %%
regions = state_region.groupby('Region').agg('sum')
regions['State Count']= state_region.groupby(by=['Region'])['State / Union territory (UT)'].count()
regions = regions.reset_index()
regions
# Out:
#          Region                       State / Union territory (UT)  \
# 0       Central                         Madhya PradeshChhattisgarh
# 1       Eastern                    OdishaBiharWest BengalJharkhand
# 2  NorthEastern  Arunachal PradeshAssamMeghalayaManipurMizoramN...
# 3      Northern  RajasthanUttar PradeshLadakhHimachal PradeshUt...
# 4      Southern  KarnatakaAndhra PradeshTamil NaduTelanganaKera...
# 5       Western  MaharashtraGujaratGoaDadra and Nagar Haveli an...
#
#    Area (km2)  National Share (%)  State Count
# 0      443541              13.480            2
# 1      418336              12.710            4
# 2      262179               7.940            8
# 3      889881              27.193           10
# 4      636251              19.330            6
# 5      508042              15.440            4

# %%
sns.set(rc={'figure.figsize':(7,6)})
ax= sns.barplot(x='Region',y='National Share (%)',data=regions)
ax.set(ylabel = "National Share")
plt.show()

# %%
sns.set(rc={'figure.figsize':(6,7)})
ax= sns.barplot(y='Region',x='State Count',data=regions)
ax.set(ylabel = "Regions")
plt.show()

# %%
plt.scatter(state_region['National Share (%)'],state_region['Area (km2)'])
plt.title('National Share Vs. Area',fontsize=20)
plt.show()

# %% [markdown]
# # **Power usage per Kilometer Square**

# %%
power_year = power
power_year['Year'] = power_year['Date'].dt.year
power_year.drop('Date',axis=1)
# Out:
#              Region  Thermal Generation Actual (in MU)  \
# index
# 0          Northern                             624.23
# 1           Western                            1106.89
# 2          Southern                             576.66
# 3           Eastern                             441.02
# 4      NorthEastern                              29.11
# ...             ...                                ...
# 305        Northern                             669.47
# 306         Western                            1116.00
# 307        Southern                             494.66
# 308         Eastern                             482.86
# 309    NorthEastern                              34.42
#
#        Thermal Generation Estimated (in MU)  \
# index
# 0                                    484.21
# 1                                   1024.33
# 2                                    578.55
# 3                                    429.39
# 4                                     15.91
# ...                                     ...
# 305                                  602.96
# 306                                 1262.10
# 307                                  415.53
# 308                                  547.03
# 309                                   32.81
#
#        Nuclear Generation Actual (in MU)  \
# index
# 0                                  30.36
# 1                                  25.17
# 2                                  62.73
# 3                                   0.00
# 4                                   0.00
# ...                                  ...
# 305                                26.88
# 306                                42.37
# 307                                61.83
# 308                                 0.00
# 309                                 0.00
#
#        Nuclear Generation Estimated (in MU)  Hydro Generation Actual (in MU)  \
# index
# 0                                     35.57                           273.27
# 1                                      3.81                            72.00
# 2                                     49.80                           111.57
# 3                                      0.00                            85.94
# 4                                      0.00                            24.64
# ...                                     ...                              ...
# 305                                   23.41                           348.72
# 306                                   36.63                            54.67
# 307                                   26.28                            93.49
# 308                                    0.00                            87.22
# 309                                    0.00                            29.87
#
#        Hydro Generation Estimated (in MU)  Total Actual Power  \
# index
# 0                                  320.81              927.86
# 1                                   21.53             1204.06
# 2                                   64.78              750.96
# 3                                   69.36              526.96
# 4                                   21.21               53.75
# ...                                   ...                 ...
# 305                                351.98             1045.07
# 306                                 20.28             1213.04
# 307                                 77.25              649.98
# 308                                 93.78              570.08
# 309                                 29.96               64.29
#
#        Total Estimated Power  Year
# index
# 0                     840.59  2017
# 1                    1049.67  2017
# 2                     693.13  2017
# 3                     498.75  2017
# 4                      37.12  2017
# ...                      ...   ...
# 305                   978.35  2020
# 306                  1319.01  2020
# 307                   519.06  2020
# 308                   640.81  2020
# 309                    62.77  2020
#
# [4945 rows x 10 columns]

# %%
power_mean_year = power_year.groupby(by=['Region'],as_index=False).mean()
power_mean_year = power_mean_year[['Region','Thermal Generation Actual (in MU)','Nuclear Generation Actual (in MU)','Hydro Generation Actual (in MU)']]
power_mean_year
# Out:
#          Region  Thermal Generation Actual (in MU)  \
# 0       Eastern                         487.486067
# 1  NorthEastern                          32.472993
# 2      Northern                         662.333933
# 3      Southern                         617.546572
# 4       Western                        1220.052224
#
#    Nuclear Generation Actual (in MU)  Hydro Generation Actual (in MU)
# 0                           0.000000                        49.228129
# 1                           0.000000                        17.808210
# 2                          27.263984                       190.954661
# 3                          56.476451                        71.900243
# 4                          27.986188                        36.638362

# %%
power_pd = pd.merge(regions,power_mean_year,how='outer')
power_pd = power_pd[power_pd.Region != 'Central']
power_pd.drop('National Share (%)',axis=1,inplace=True)
power_pd.drop('State Count',axis=1,inplace=True)
power_pd
# Out:
#          Region                       State / Union territory (UT)  \
# 1       Eastern                    OdishaBiharWest BengalJharkhand
# 2  NorthEastern  Arunachal PradeshAssamMeghalayaManipurMizoramN...
# 3      Northern  RajasthanUttar PradeshLadakhHimachal PradeshUt...
# 4      Southern  KarnatakaAndhra PradeshTamil NaduTelanganaKera...
# 5       Western  MaharashtraGujaratGoaDadra and Nagar Haveli an...
#
#    Area (km2)  Thermal Generation Actual (in MU)  \
# 1      418336                         487.486067
# 2      262179                          32.472993
# 3      889881                         662.333933
# 4      636251                         617.546572
# 5      508042                        1220.052224
#
#    Nuclear Generation Actual (in MU)  Hydro Generation Actual (in MU)
# 1                           0.000000                        49.228129
# 2                           0.000000                        17.808210
# 3                          27.263984                       190.954661
# 4                          56.476451                        71.900243
# 5                          27.986188                        36.638362

# %%
power_pd['Thermal/Km2'] = (power_pd['Thermal Generation Actual (in MU)']/power_pd['Area (km2)'])
power_pd['Nuclear/Km2'] = (power_pd['Nuclear Generation Actual (in MU)']/power_pd['Area (km2)'])
power_pd['Hydro/Km2'] = (power_pd['Hydro Generation Actual (in MU)']/power_pd['Area (km2)'])
power_pd
# Out:
#          Region                       State / Union territory (UT)  \
# 1       Eastern                    OdishaBiharWest BengalJharkhand
# 2  NorthEastern  Arunachal PradeshAssamMeghalayaManipurMizoramN...
# 3      Northern  RajasthanUttar PradeshLadakhHimachal PradeshUt...
# 4      Southern  KarnatakaAndhra PradeshTamil NaduTelanganaKera...
# 5       Western  MaharashtraGujaratGoaDadra and Nagar Haveli an...
#
#    Area (km2)  Thermal Generation Actual (in MU)  \
# 1      418336                         487.486067
# 2      262179                          32.472993
# 3      889881                         662.333933
# 4      636251                         617.546572
# 5      508042                        1220.052224
#
#    Nuclear Generation Actual (in MU)  Hydro Generation Actual (in MU)  \
# 1                           0.000000                        49.228129
# 2                           0.000000                        17.808210
# 3                          27.263984                       190.954661
# 4                          56.476451                        71.900243
# 5                          27.986188                        36.638362
#
#    Thermal/Km2  Nuclear/Km2  Hydro/Km2
# 1     0.001165     0.000000   0.000118
# 2     0.000124     0.000000   0.000068
# 3     0.000744     0.000031   0.000215
# 4     0.000971     0.000089   0.000113
# 5     0.002401     0.000055   0.000072

# %%
power_pd_melt = pd.melt(power_pd,id_vars=['Region'],value_vars=['Thermal/Km2','Nuclear/Km2','Hydro/Km2'])
power_pd_melt
# Out:
#           Region     variable     value
# 0        Eastern  Thermal/Km2  0.001165
# 1   NorthEastern  Thermal/Km2  0.000124
# 2       Northern  Thermal/Km2  0.000744
# 3       Southern  Thermal/Km2  0.000971
# 4        Western  Thermal/Km2  0.002401
# 5        Eastern  Nuclear/Km2  0.000000
# 6   NorthEastern  Nuclear/Km2  0.000000
# 7       Northern  Nuclear/Km2  0.000031
# 8       Southern  Nuclear/Km2  0.000089
# 9        Western  Nuclear/Km2  0.000055
# 10       Eastern    Hydro/Km2  0.000118
# 11  NorthEastern    Hydro/Km2  0.000068
# 12      Northern    Hydro/Km2  0.000215
# 13      Southern    Hydro/Km2  0.000113
# 14       Western    Hydro/Km2  0.000072

# %%
plt.figure(figsize=(10,6))
ax=sns.barplot(x='Region',y='value',hue='variable',data=power_pd_melt)
ax.set(ylabel = "Value")
plt.show()

# %% [markdown]
# *   Thermal Power dominant in every Region.
# *   No Nuclear plants in Eastern and NorhtEastern Regions
#
# # **Splitting data region wise - by using boolean mask**
#
# **Northern Region**

# %%
# Mask for Northern Region
mask_northern = power['Region'] == 'Northern'
mask_northern
# Out:
# index
# 0       True
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 305     True
# 306    False
# 307    False
# 308    False
# 309    False
# Name: Region, Length: 4945, dtype: bool

# %%
# Extract the Northern data into a dataframe
df_Northern = power[mask_northern]
df_Northern
# Out:
#             Date    Region  Thermal Generation Actual (in MU)  \
# index
# 0     2017-09-01  Northern                             624.23
# 5     2017-09-02  Northern                             624.23
# 10    2017-09-03  Northern                             624.23
# 15    2017-09-04  Northern                             624.23
# 20    2017-09-05  Northern                             628.58
# ...          ...       ...                                ...
# 285   2020-07-28  Northern                             708.11
# 290   2020-07-29  Northern                             708.11
# 295   2020-07-30  Northern                             708.11
# 300   2020-07-31  Northern                             708.11
# 305   2020-08-01  Northern                             669.47
#
#        Thermal Generation Estimated (in MU)  \
# index
# 0                                    484.21
# 5                                    507.42
# 10                                   492.69
# 15                                   568.34
# 20                                   597.08
# ...                                     ...
# 285                                  680.40
# 290                                  655.40
# 295                                  612.32
# 300                                  625.88
# 305                                  602.96
#
#        Nuclear Generation Actual (in MU)  \
# index
# 0                                  30.36
# 5                                  30.36
# 10                                 30.36
# 15                                 30.36
# 20                                 30.36
# ...                                  ...
# 285                                26.88
# 290                                26.88
# 295                                26.88
# 300                                26.88
# 305                                26.88
#
#        Nuclear Generation Estimated (in MU)  Hydro Generation Actual (in MU)  \
# index
# 0                                     35.57                           273.27
# 5                                     35.69                           273.27
# 10                                    35.65                           273.27
# 15                                    35.62                           273.27
# 20                                    35.72                           273.27
# ...                                     ...                              ...
# 285                                   27.16                           327.08
# 290                                   28.23                           327.08
# 295                                   22.77                           327.08
# 300                                   22.78                           327.08
# 305                                   23.41                           348.72
#
#        Hydro Generation Estimated (in MU)  Total Actual Power  \
# index
# 0                                  320.81              927.86
# 5                                  317.19              927.86
# 10                                 316.69              927.86
# 15                                 297.47              927.86
# 20                                 290.23              932.21
# ...                                   ...                 ...
# 285                                352.65             1062.07
# 290                                348.00             1062.07
# 295                                343.59             1062.07
# 300                                348.39             1062.07
# 305                                351.98             1045.07
#
#        Total Estimated Power  Year
# index
# 0                     840.59  2017
# 5                     860.30  2017
# 10                    845.03  2017
# 15                    901.43  2017
# 20                    923.03  2017
# ...                      ...   ...
# 285                  1060.21  2020
# 290                  1031.63  2020
# 295                   978.68  2020
# 300                   997.05  2020
# 305                   978.35  2020
#
# [989 rows x 11 columns]

# %%
# Saving Northern Region data as csv
df_Northern.to_csv('Northern.csv')

# %% [markdown]
# ## **Western Region**

# %%
# Mask for Western Region
mask_western = power['Region'] == 'Western'
mask_western
# Out:
# index
# 0      False
# 1       True
# 2      False
# 3      False
# 4      False
#        ...
# 305    False
# 306     True
# 307    False
# 308    False
# 309    False
# Name: Region, Length: 4945, dtype: bool

# %%
# Extract the Western data into a dataframe
df_Western = power[mask_western]
df_Western
# Out:
#             Date   Region  Thermal Generation Actual (in MU)  \
# index
# 1     2017-09-01  Western                            1106.89
# 6     2017-09-02  Western                            1106.89
# 11    2017-09-03  Western                            1106.89
# 16    2017-09-04  Western                            1106.89
# 21    2017-09-05  Western                            1106.89
# ...          ...      ...                                ...
# 286   2020-07-28  Western                            1182.24
# 291   2020-07-29  Western                            1182.24
# 296   2020-07-30  Western                            1194.97
# 301   2020-07-31  Western                            1199.28
# 306   2020-08-01  Western                            1116.00
#
#        Thermal Generation Estimated (in MU)  \
# index
# 1                                   1024.33
# 6                                   1050.91
# 11                                  1066.73
# 16                                  1115.43
# 21                                  1131.78
# ...                                     ...
# 286                                 1282.43
# 291                                 1271.90
# 296                                 1279.02
# 301                                 1288.65
# 306                                 1262.10
#
#        Nuclear Generation Actual (in MU)  \
# index
# 1                                  25.17
# 6                                  25.17
# 11                                 25.17
# 16                                 25.17
# 21                                 25.17
# ...                                  ...
# 286                                42.37
# 291                                42.37
# 296                                42.37
# 301                                42.37
# 306                                42.37
#
#        Nuclear Generation Estimated (in MU)  Hydro Generation Actual (in MU)  \
# index
# 1                                      3.81                            72.00
# 6                                      3.83                            72.00
# 11                                     3.80                            72.00
# 16                                     3.81                            72.00
# 21                                     3.83                            72.00
# ...                                     ...                              ...
# 286                                   36.80                            29.75
# 291                                   36.65                            29.75
# 296                                   36.62                            29.75
# 301                                   36.68                            29.75
# 306                                   36.63                            54.67
#
#        Hydro Generation Estimated (in MU)  Total Actual Power  \
# index
# 1                                   21.53             1204.06
# 6                                   23.97             1204.06
# 11                                  13.94             1204.06
# 16                                  37.38             1204.06
# 21                                  28.78             1204.06
# ...                                   ...                 ...
# 286                                 25.94             1254.36
# 291                                 21.91             1254.36
# 296                                 24.46             1267.09
# 301                                 19.26             1271.40
# 306                                 20.28             1213.04
#
#        Total Estimated Power  Year
# index
# 1                    1049.67  2017
# 6                    1078.71  2017
# 11                   1084.47  2017
# 16                   1156.62  2017
# 21                   1164.39  2017
# ...                      ...   ...
# 286                  1345.17  2020
# 291                  1330.46  2020
# 296                  1340.10  2020
# 301                  1344.59  2020
# 306                  1319.01  2020
#
# [989 rows x 11 columns]

# %%
# Saving Western Region data as csv
df_Western.to_csv('Western.csv')

# %% [markdown]
# **Southern Region**

# %%
# Mask for Southern Region
mask_southern = power['Region'] == 'Southern'
mask_southern
# Out:
# index
# 0      False
# 1      False
# 2       True
# 3      False
# 4      False
#        ...
# 305    False
# 306    False
# 307     True
# 308    False
# 309    False
# Name: Region, Length: 4945, dtype: bool

# %%
# Extract the Southern data into a dataframe
df_Southern = power[mask_southern]
df_Southern
# Out:
#             Date    Region  Thermal Generation Actual (in MU)  \
# index
# 2     2017-09-01  Southern                             576.66
# 7     2017-09-02  Southern                             576.66
# 12    2017-09-03  Southern                             572.16
# 17    2017-09-04  Southern                             572.16
# 22    2017-09-05  Southern                             576.35
# ...          ...       ...                                ...
# 287   2020-07-28  Southern                             538.60
# 292   2020-07-29  Southern                             538.60
# 297   2020-07-30  Southern                             538.60
# 302   2020-07-31  Southern                             543.60
# 307   2020-08-01  Southern                             494.66
#
#        Thermal Generation Estimated (in MU)  \
# index
# 2                                    578.55
# 7                                    562.79
# 12                                   530.68
# 17                                   562.81
# 22                                   575.06
# ...                                     ...
# 287                                  446.86
# 292                                  431.01
# 297                                  424.59
# 302                                  444.43
# 307                                  415.53
#
#        Nuclear Generation Actual (in MU)  \
# index
# 2                                  62.73
# 7                                  62.73
# 12                                 62.73
# 17                                 62.73
# 22                                 62.73
# ...                                  ...
# 287                                61.83
# 292                                61.83
# 297                                61.83
# 302                                61.83
# 307                                61.83
#
#        Nuclear Generation Estimated (in MU)  Hydro Generation Actual (in MU)  \
# index
# 2                                     49.80                           111.57
# 7                                     52.76                           111.57
# 12                                    53.12                           111.57
# 17                                    53.19                           111.57
# 22                                    53.16                           111.57
# ...                                     ...                              ...
# 287                                   25.36                            61.43
# 292                                   25.40                            61.43
# 297                                   26.25                            61.43
# 302                                   26.21                            61.43
# 307                                   26.28                            93.49
#
#        Hydro Generation Estimated (in MU)  Total Actual Power  \
# index
# 2                                   64.78              750.96
# 7                                   59.49              750.96
# 12                                  47.53              746.46
# 17                                  66.20              746.46
# 22                                  58.00              750.65
# ...                                   ...                 ...
# 287                                 97.89              661.86
# 292                                 84.27              661.86
# 297                                 84.27              661.86
# 302                                 85.42              666.86
# 307                                 77.25              649.98
#
#        Total Estimated Power  Year
# index
# 2                     693.13  2017
# 7                     675.04  2017
# 12                    631.33  2017
# 17                    682.20  2017
# 22                    686.22  2017
# ...                      ...   ...
# 287                   570.11  2020
# 292                   540.68  2020
# 297                   535.11  2020
# 302                   556.06  2020
# 307                   519.06  2020
#
# [989 rows x 11 columns]

# %%
# Saving Southern Region data as csv
df_Southern.to_csv('Southern.csv')

# %% [markdown]
# **Eastern Region**

# %%
# Mask for Eastern Region
mask_eastern = power['Region'] == 'Eastern'
mask_eastern
# Out:
# index
# 0      False
# 1      False
# 2      False
# 3       True
# 4      False
#        ...
# 305    False
# 306    False
# 307    False
# 308     True
# 309    False
# Name: Region, Length: 4945, dtype: bool

# %%
# Extract the Eastern data into a dataframe
df_Eastern = power[mask_eastern]
df_Eastern
# Out:
#             Date   Region  Thermal Generation Actual (in MU)  \
# index
# 3     2017-09-01  Eastern                             441.02
# 8     2017-09-02  Eastern                             441.02
# 13    2017-09-03  Eastern                             445.38
# 18    2017-09-04  Eastern                             445.38
# 23    2017-09-05  Eastern                             449.92
# ...          ...      ...                                ...
# 288   2020-07-28  Eastern                             496.03
# 293   2020-07-29  Eastern                             496.03
# 298   2020-07-30  Eastern                             496.03
# 303   2020-07-31  Eastern                             496.03
# 308   2020-08-01  Eastern                             482.86
#
#        Thermal Generation Estimated (in MU)  \
# index
# 3                                    429.39
# 8                                    425.75
# 13                                   427.61
# 18                                   450.85
# 23                                   459.09
# ...                                     ...
# 288                                  542.80
# 293                                  529.92
# 298                                  537.09
# 303                                  553.21
# 308                                  547.03
#
#        Nuclear Generation Actual (in MU)  \
# index
# 3                                    0.0
# 8                                    0.0
# 13                                   0.0
# 18                                   0.0
# 23                                   0.0
# ...                                  ...
# 288                                  0.0
# 293                                  0.0
# 298                                  0.0
# 303                                  0.0
# 308                                  0.0
#
#        Nuclear Generation Estimated (in MU)  Hydro Generation Actual (in MU)  \
# index
# 3                                       0.0                            85.94
# 8                                       0.0                            85.94
# 13                                      0.0                            85.94
# 18                                      0.0                            85.94
# 23                                      0.0                            85.94
# ...                                     ...                              ...
# 288                                     0.0                            80.00
# 293                                     0.0                            80.00
# 298                                     0.0                            80.00
# 303                                     0.0                            80.00
# 308                                     0.0                            87.22
#
#        Hydro Generation Estimated (in MU)  Total Actual Power  \
# index
# 3                                   69.36              526.96
# 8                                   74.18              526.96
# 13                                  71.05              531.32
# 18                                  75.21              531.32
# 23                                  70.29              535.86
# ...                                   ...                 ...
# 288                                 82.94              576.03
# 293                                 85.44              576.03
# 298                                 87.26              576.03
# 303                                 96.30              576.03
# 308                                 93.78              570.08
#
#        Total Estimated Power  Year
# index
# 3                     498.75  2017
# 8                     499.93  2017
# 13                    498.66  2017
# 18                    526.06  2017
# 23                    529.38  2017
# ...                      ...   ...
# 288                   625.74  2020
# 293                   615.36  2020
# 298                   624.35  2020
# 303                   649.51  2020
# 308                   640.81  2020
#
# [989 rows x 11 columns]

# %%
# Saving Eastern Region data as csv
df_Eastern.to_csv('Eastern.csv')

# %% [markdown]
# **NorthEastern Region**

# %%
mask_northEast = power['Region'] == 'NorthEastern'
mask_northEast
# Out:
# index
# 0      False
# 1      False
# 2      False
# 3      False
# 4       True
#        ...
# 305    False
# 306    False
# 307    False
# 308    False
# 309     True
# Name: Region, Length: 4945, dtype: bool

# %%
# Extract the NorthEastern data into a dataframe
df_NorthEastern = power[mask_northEast]
df_NorthEastern
# Out:
#             Date        Region  Thermal Generation Actual (in MU)  \
# index
# 4     2017-09-01  NorthEastern                              29.11
# 9     2017-09-02  NorthEastern                              29.11
# 14    2017-09-03  NorthEastern                              29.11
# 19    2017-09-04  NorthEastern                              29.11
# 24    2017-09-05  NorthEastern                              29.11
# ...          ...           ...                                ...
# 289   2020-07-28  NorthEastern                              36.65
# 294   2020-07-29  NorthEastern                              36.65
# 299   2020-07-30  NorthEastern                              36.65
# 304   2020-07-31  NorthEastern                              36.98
# 309   2020-08-01  NorthEastern                              34.42
#
#        Thermal Generation Estimated (in MU)  \
# index
# 4                                     15.91
# 9                                     16.50
# 14                                    15.52
# 19                                    16.85
# 24                                    16.64
# ...                                     ...
# 289                                   33.55
# 294                                   30.63
# 299                                   30.86
# 304                                   30.94
# 309                                   32.81
#
#        Nuclear Generation Actual (in MU)  \
# index
# 4                                    0.0
# 9                                    0.0
# 14                                   0.0
# 19                                   0.0
# 24                                   0.0
# ...                                  ...
# 289                                  0.0
# 294                                  0.0
# 299                                  0.0
# 304                                  0.0
# 309                                  0.0
#
#        Nuclear Generation Estimated (in MU)  Hydro Generation Actual (in MU)  \
# index
# 4                                       0.0                            24.64
# 9                                       0.0                            24.64
# 14                                      0.0                            24.64
# 19                                      0.0                            24.64
# 24                                      0.0                            24.64
# ...                                     ...                              ...
# 289                                     0.0                            27.51
# 294                                     0.0                            27.51
# 299                                     0.0                            27.51
# 304                                     0.0                            27.51
# 309                                     0.0                            29.87
#
#        Hydro Generation Estimated (in MU)  Total Actual Power  \
# index
# 4                                   21.21               53.75
# 9                                   20.81               53.75
# 14                                  23.84               53.75
# 19                                  24.10               53.75
# 24                                  22.86               53.75
# ...                                   ...                 ...
# 289                                 30.08               64.16
# 294                                 30.19               64.16
# 299                                 30.20               64.16
# 304                                 29.76               64.49
# 309                                 29.96               64.29
#
#        Total Estimated Power  Year
# index
# 4                      37.12  2017
# 9                      37.31  2017
# 14                     39.36  2017
# 19                     40.95  2017
# 24                     39.50  2017
# ...                      ...   ...
# 289                    63.63  2020
# 294                    60.82  2020
# 299                    61.06  2020
# 304                    60.70  2020
# 309                    62.77  2020
#
# [989 rows x 11 columns]

# %%
# Saving NorthEastern Region data as csv
df_NorthEastern.to_csv('NorthEastern.csv')

# %% [markdown]
# **Analysis of model on overall dataset grouping by date**

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler,Normalizer
from sklearn.linear_model import LinearRegression

# %%
mean_power = power.groupby(by='Date',as_index=False).mean(numeric_only=True)
mean_power
# Out:
#           Date  Thermal Generation Actual (in MU)  \
# 0   2017-09-01                            555.582
# 1   2017-09-02                            555.582
# 2   2017-09-03                            555.554
# 3   2017-09-04                            555.554
# 4   2017-09-05                            558.170
# ..         ...                                ...
# 984 2020-07-28                            592.326
# 985 2020-07-29                            592.326
# 986 2020-07-30                            594.872
# 987 2020-07-31                            596.800
# 988 2020-08-01                            559.482
#
#      Thermal Generation Estimated (in MU)  Nuclear Generation Actual (in MU)  \
# 0                                 506.478                             23.652
# 1                                 512.674                             23.652
# 2                                 506.646                             23.652
# 3                                 542.856                             23.652
# 4                                 555.930                             23.652
# ..                                    ...                                ...
# 984                               597.208                             26.216
# 985                               583.772                             26.216
# 986                               576.776                             26.216
# 987                               588.622                             26.216
# 988                               572.086                             26.216
#
#      Nuclear Generation Estimated (in MU)  Hydro Generation Actual (in MU)  \
# 0                                  17.836                          113.484
# 1                                  18.456                          113.484
# 2                                  18.514                          113.484
# 3                                  18.524                          113.484
# 4                                  18.542                          113.484
# ..                                    ...                              ...
# 984                                17.864                          105.154
# 985                                18.056                          105.154
# 986                                17.128                          105.154
# 987                                17.134                          105.154
# 988                                17.264                          122.794
#
#      Hydro Generation Estimated (in MU)  Total Actual Power  \
# 0                                99.538             692.718
# 1                                99.128             692.718
# 2                                94.610             692.690
# 3                               100.072             692.690
# 4                                94.032             695.306
# ..                                  ...                 ...
# 984                             117.900             723.696
# 985                             113.962             723.696
# 986                             113.956             726.242
# 987                             115.826             728.170
# 988                             114.650             708.492
#
#      Total Estimated Power    Year
# 0                  623.852  2017.0
# 1                  630.258  2017.0
# 2                  619.770  2017.0
# 3                  661.452  2017.0
# 4                  668.504  2017.0
# ..                     ...     ...
# 984                732.972  2020.0
# 985                715.790  2020.0
# 986                707.860  2020.0
# 987                721.582  2020.0
# 988                704.000  2020.0
#
# [989 rows x 10 columns]

# %% [markdown]
# # **Linear Regression Model for Hydro Energy Generated**

# %%
mean_hydro = mean_power[['Hydro Generation Estimated (in MU)','Hydro Generation Actual (in MU)']]
mean_hydro
# Out:
#      Hydro Generation Estimated (in MU)  Hydro Generation Actual (in MU)
# 0                                99.538                          113.484
# 1                                99.128                          113.484
# 2                                94.610                          113.484
# 3                               100.072                          113.484
# 4                                94.032                          113.484
# ..                                  ...                              ...
# 984                             117.900                          105.154
# 985                             113.962                          105.154
# 986                             113.956                          105.154
# 987                             115.826                          105.154
# 988                             114.650                          122.794
#
# [989 rows x 2 columns]

# %%
mean_hydro.boxplot()
# Out:
# <Axes: >

# %%
x = mean_hydro[['Hydro Generation Estimated (in MU)']].values
y = mean_hydro[['Hydro Generation Actual (in MU)']].values

x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=42)

# %%
linreg = LinearRegression()
linreg.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = linreg.predict(x_test)

# %%
plt.figure(figsize=(18,9))

plt.scatter(x_test,y_test)
plt.plot(x_test,y_pred,color='r')
plt.show()

# %%
linreg.score(x_train,y_train)
# Out:
# 0.8045683939079786

# %%
from sklearn.metrics import r2_score

score = r2_score(y_test,y_pred)

print(f'Test score : {score}')
# Out:
# Test score : 0.7924985669078575

# %%
f'Slope : {linreg.coef_}'
# Out:
# 'Slope : [[0.75180713]]'

# %%
f'Intercept : {linreg.intercept_}'
# Out:
# 'Intercept : [15.66058414]'

# %% [markdown]
# # **Region wise Model Training and Testing**
# Eastern Region Hydro Energy

# %%
e_hydro = df_Eastern[['Hydro Generation Estimated (in MU)','Hydro Generation Actual (in MU)']]
e_hydro
# Out:
#        Hydro Generation Estimated (in MU)  Hydro Generation Actual (in MU)
# index
# 3                                   69.36                            85.94
# 8                                   74.18                            85.94
# 13                                  71.05                            85.94
# 18                                  75.21                            85.94
# 23                                  70.29                            85.94
# ...                                   ...                              ...
# 288                                 82.94                            80.00
# 293                                 85.44                            80.00
# 298                                 87.26                            80.00
# 303                                 96.30                            80.00
# 308                                 93.78                            87.22
#
# [989 rows x 2 columns]

# %%
xeh = e_hydro[['Hydro Generation Estimated (in MU)']].values
yeh = e_hydro[['Hydro Generation Actual (in MU)']].values

x_ehtrain,x_ehtest,y_ehtrain,y_ehtest = train_test_split(xeh,yeh,test_size=0.2,random_state=42)

# %%
linreg.fit(x_ehtrain,y_ehtrain)
# Out:
# LinearRegression()

# %%
y_ehpred = linreg.predict(x_ehtest)

# %%
linreg.score(x_ehtrain,y_ehtrain)
# Out:
# 0.8463750133847041

# %%
from sklearn.metrics import r2_score

score = r2_score(y_ehtest,y_ehpred)

print(f'Test score : {score}')
# Out:
# Test score : 0.8524215847946875

# %%
f'Slope : {linreg.coef_}'
# Out:
# 'Slope : [[0.84784935]]'

# %%
f'Intercept : {linreg.intercept_}'
# Out:
# 'Intercept : [4.24414948]'

# %% [markdown]
# # **Western Region Hydro Energy**

# %%
w_hydro = df_Western[['Hydro Generation Estimated (in MU)','Hydro Generation Actual (in MU)']]
w_hydro
# Out:
#        Hydro Generation Estimated (in MU)  Hydro Generation Actual (in MU)
# index
# 1                                   21.53                            72.00
# 6                                   23.97                            72.00
# 11                                  13.94                            72.00
# 16                                  37.38                            72.00
# 21                                  28.78                            72.00
# ...                                   ...                              ...
# 286                                 25.94                            29.75
# 291                                 21.91                            29.75
# 296                                 24.46                            29.75
# 301                                 19.26                            29.75
# 306                                 20.28                            54.67
#
# [989 rows x 2 columns]

# %%
xwh = w_hydro[['Hydro Generation Estimated (in MU)']].values
ywh = w_hydro[['Hydro Generation Actual (in MU)']].values

x_whtrain,x_whtest,y_whtrain,y_whtest = train_test_split(xwh,ywh,test_size=0.2,random_state=42)

# %%
linreg.fit(x_whtrain,y_whtrain)
# Out:
# LinearRegression()

# %%
y_whpred = linreg.predict(x_whtest)

# %%
linreg.score(x_whtrain,y_whtrain)
# Out:
# 0.00938336609421464

# %%
linreg.score(x_whtrain,y_whtrain)
# Out:
# 0.00938336609421464

# %%
from sklearn.metrics import r2_score

score = r2_score(y_whtest,y_whpred)

print(f'Test score : {score}')
# Out:
# Test score : 0.01416667542697203

# %%
f'Slope : {linreg.coef_}'
# Out:
# 'Slope : [[0.04879786]]'

# %%
f'Intercept : {linreg.intercept_}'
# Out:
# 'Intercept : [35.06287848]'

# %% [markdown]
# # **Northern Region Hydro Energy**

# %%
n_hydro = df_Northern[['Hydro Generation Estimated (in MU)','Hydro Generation Actual (in MU)']]
n_hydro
# Out:
#        Hydro Generation Estimated (in MU)  Hydro Generation Actual (in MU)
# index
# 0                                  320.81                           273.27
# 5                                  317.19                           273.27
# 10                                 316.69                           273.27
# 15                                 297.47                           273.27
# 20                                 290.23                           273.27
# ...                                   ...                              ...
# 285                                352.65                           327.08
# 290                                348.00                           327.08
# 295                                343.59                           327.08
# 300                                348.39                           327.08
# 305                                351.98                           348.72
#
# [989 rows x 2 columns]

# %%
xnh = n_hydro[['Hydro Generation Estimated (in MU)']].values
ynh = n_hydro[['Hydro Generation Actual (in MU)']].values

x_nhtrain,x_nhtest,y_nhtrain,y_nhtest = train_test_split(xnh,ynh,test_size=0.2,random_state=42)

# %%
linreg.fit(x_nhtrain,y_nhtrain)
# Out:
# LinearRegression()

# %%
y_nhpred = linreg.predict(x_nhtest)

# %%
linreg.score(x_nhtrain,y_nhtrain)
# Out:
# 0.8962246561468603

# %%
from sklearn.metrics import r2_score

score = r2_score(y_nhtest,y_nhpred)

print(f'Test score : {score}')
# Out:
# Test score : 0.8694924844385487

# %%
f'Slope : {linreg.coef_}'
# Out:
# 'Slope : [[0.87506754]]'

# %%
f'Intercept : {linreg.intercept_}'
# Out:
# 'Intercept : [12.89113541]'

# %% [markdown]
# # **Southern Region Hydro Energy**

# %%
s_hydro = df_Southern[['Hydro Generation Estimated (in MU)','Hydro Generation Actual (in MU)']]
s_hydro
# Out:
#        Hydro Generation Estimated (in MU)  Hydro Generation Actual (in MU)
# index
# 2                                   64.78                           111.57
# 7                                   59.49                           111.57
# 12                                  47.53                           111.57
# 17                                  66.20                           111.57
# 22                                  58.00                           111.57
# ...                                   ...                              ...
# 287                                 97.89                            61.43
# 292                                 84.27                            61.43
# 297                                 84.27                            61.43
# 302                                 85.42                            61.43
# 307                                 77.25                            93.49
#
# [989 rows x 2 columns]

# %%
xsh = s_hydro[['Hydro Generation Estimated (in MU)']].values
ysh = s_hydro[['Hydro Generation Actual (in MU)']].values

x_shtrain,x_shtest,y_shtrain,y_shtest = train_test_split(xsh,ysh,test_size=0.2,random_state=42)

# %%
linreg.fit(x_shtrain,y_shtrain)
# Out:
# LinearRegression()

# %%
y_shpred = linreg.predict(x_shtest)

# %%
linreg.score(x_shtrain,y_shtrain)
# Out:
# 0.20005216366592304

# %%
from sklearn.metrics import r2_score

score = r2_score(y_shtest,y_shpred)

print(f'Test score : {score}')
# Out:
# Test score : 0.2455497844602178

# %%
f'Slope : {linreg.coef_}'
# Out:
# 'Slope : [[0.22153932]]'

# %%
f'Intercept : {linreg.intercept_}'
# Out:
# 'Intercept : [54.81401521]'

# %% [markdown]
# # **NorthEastern Region Hydro Energy**

# %%
ne_hydro = df_NorthEastern[['Hydro Generation Estimated (in MU)','Hydro Generation Actual (in MU)']]
ne_hydro
# Out:
#        Hydro Generation Estimated (in MU)  Hydro Generation Actual (in MU)
# index
# 4                                   21.21                            24.64
# 9                                   20.81                            24.64
# 14                                  23.84                            24.64
# 19                                  24.10                            24.64
# 24                                  22.86                            24.64
# ...                                   ...                              ...
# 289                                 30.08                            27.51
# 294                                 30.19                            27.51
# 299                                 30.20                            27.51
# 304                                 29.76                            27.51
# 309                                 29.96                            29.87
#
# [989 rows x 2 columns]

# %%
xneh= ne_hydro[['Hydro Generation Estimated (in MU)']].values
yneh= ne_hydro[['Hydro Generation Actual (in MU)']].values

x_nehtrain,x_nehtest,y_nehtrain,y_nehtest = train_test_split(xneh,yneh,test_size=0.2,random_state=42)

# %%
linreg.fit(x_nehtrain,y_nehtrain)
# Out:
# LinearRegression()

# %%
y_nehpred = linreg.predict(x_nehtest)

# %%
linreg.score(x_nehtrain,y_nehtrain)
# Out:
# 0.7281576882533387

# %%
from sklearn.metrics import r2_score

score = r2_score(y_nehtest,y_nehpred)

print(f'Test score : {score}')
# Out:
# Test score : 0.7149263218747328

# %%
f'Slope : {linreg.coef_}'
# Out:
# 'Slope : [[0.85473544]]'

# %%
f'Intercept : {linreg.intercept_}'
# Out:
# 'Intercept : [5.60930189]'

# %% [markdown]
# # **Linear Regression Model for Nuclear Energy Generated**

# %%
mean_nuclear = mean_power[['Nuclear Generation Estimated (in MU)','Nuclear Generation Actual (in MU)']]
mean_nuclear
# Out:
#      Nuclear Generation Estimated (in MU)  Nuclear Generation Actual (in MU)
# 0                                  17.836                             23.652
# 1                                  18.456                             23.652
# 2                                  18.514                             23.652
# 3                                  18.524                             23.652
# 4                                  18.542                             23.652
# ..                                    ...                                ...
# 984                                17.864                             26.216
# 985                                18.056                             26.216
# 986                                17.128                             26.216
# 987                                17.134                             26.216
# 988                                17.264                             26.216
#
# [989 rows x 2 columns]

# %%
mean_nuclear.boxplot()
# Out:
# <Axes: >

# %%
x = mean_nuclear[['Nuclear Generation Estimated (in MU)']].values
y = mean_nuclear[['Nuclear Generation Actual (in MU)']].values

x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=42)

# %%
linreg = LinearRegression()
linreg.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = linreg.predict(x_test)

# %%
plt.figure(figsize=(18,9))

plt.scatter(x_test,y_test)
plt.plot(x_test,y_pred,color='r')
plt.show()
